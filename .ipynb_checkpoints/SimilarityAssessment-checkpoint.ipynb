# %%
import pandas as pd

# %%
IF_SS = pd.read_csv("if_ss.csv")
# Out:
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (2,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
IF = pd.read_csv("Spatial_Parcel_AAL_if2.csv")
SS= pd.read_csv("Spatial_Parcel_AAL_ss.csv")
# Out:
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (10,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (3,19,20,22,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
print("IF_SS",IF_SS.columns)
print("IF",IF.columns)
print("SS",SS.columns)
print(len(IF_SS))
# Out:
# IF_SS Index(['OBJECTID_1', 'Parcel', 'Bldg_Quali', 'State_Code', 'Residentia',
#        'Imp_Code', 'Bldg_No', 'Exterior_F', 'Bldg_Area', 'Foundation',
#        'Year_Built', 'Land_Value', 'Imp_Value', 'County', 'Market_Val',
#        'Storey', 'Longitude', 'Latitude', 'Assumed_FF', 'SFHA_TF', 'FLD_ZONE',
#        'Longitude_', 'Latitude_', 'TotalRepla', 'AAL_IF', 'AAL_SS',
#        'Harvey_Dep', 'Ike_Base', 'Ike_Dike', 'FIPS'],
#       dtype='object')
# IF Index(['OBJECTID_1', 'Join_Count', 'TARGET_FID', 'Join_Count_1',
#        'TARGET_FID_1', 'OBJECTID', 'Parcel_ID', 'State_Code', 'Bldg_Quali',
#        'Residentia', 'Imp_Code', 'Bldg_No', 'Exterior_F', 'Foundation',
#        'Year_Built', 'Bldg_Area', 'land_Value', 'Imp_Value', 'Market_Val',
#        'Storey', 'County', 'Longitude', 'Latitude', 'Assumed_FF', 'FLD_AR_ID',
#        'SFHA_TF', 'STATIC_BFE', 'V_DATUM', 'DEPTH', 'BFE_REVERT', 'DEP_REVERT',
# ...

# %%
print("flooded")
print(len(IF_SS[IF_SS.Harvey_Dep >0])-len(IF[IF.Harvey_Depth >0 ]))
print(len(IF_SS[IF_SS.Harvey_Dep >0]))
print(len(IF[IF.Harvey_Depth >0 ]))
print("AAL")
print(len(IF_SS[IF_SS.AAL_IF >0]) - len(IF[IF.AAL >0 ]))
# print(len(IF[IF.AAL >0 ]))
# Out:
# flooded
# 61943
# 248895
# 186952
# AAL
# 417995

# %%
print("flooded")
print(len(IF_SS[IF_SS.Ike_Base >0])-len(SS[SS.Ike_Base >0 ]))
print("NEW",len(IF_SS[IF_SS.Ike_Base >0]))
print("OLD",len(SS[SS.Ike_Base >0 ]))
print("AAL")
print(len(IF_SS[IF_SS.AAL_SS >0])-len(SS[SS.AAL >0 ]))
# print(len(SS[SS.AAL >0 ]))
# Out:
# flooded
# -14431
# NEW 24704
# OLD 39135
# AAL
# 20012

# %%
df = pd.read_csv("Test.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Parcel', 'Foundation', 'Imp_Value', 'Imp_Code',
#        'Bldg_Quali', 'FLD_ZONE', 'TotalRepla', 'Year_Built', 'Exterior_F',
#        'Latitude', 'Longitude', 'Market_Val', 'State_Code', 'County', 'Storey',
#        'Bldg_Area', 'Assumed_FF', 'Land_Value', 'FIPS', 'AAL_IF', 'AAL_SS',
#        'Harvey_Dep', 'Ike_Base', 'Inundated_Base', 'geometry', 'x_range_0',
#        'y_range_0', 'range', 'Nearest', 'Claims', 'Claims_PV', 'Ike_PV', 'Ike',
#        'Harvey', 'Harvey_PV', 'All_Claims', 'All_Claims_PV',
#        'extra_elevation_SS', 'extra_elevation_IF', 'Buyouts_Cost', 'REL',
#        'Buyout_AAL_Savings', 'Buyout_Savings', 'Weighted_Buyouts_BCR',
#        'Buyouts_BCR', 'Elevation_Cost_1ft', 'Elevation_Est_Damage',
#        'Est_Damage', 'Elevation_Savings', 'Elevation_BCR', 'Buyout_Rolling'],
#       dtype='object')

# %%
df[["Weighted_Buyouts_BCR", "Buyouts_BCR"]].mean()
# Out:
# Weighted_Buyouts_BCR   -0.041354
# Buyouts_BCR            -0.041354
# dtype: float64

# %%
df.Nearest.to_dict()
# Out:
# {0: "[{'distance': 195.49333108793772, 'Parcel': 417982.0}, {'distance': 1384.1656911298612, 'Parcel': 417982.0}, {'distance': 1405.837446648739, 'Parcel': 417982.0}, {'distance': 1509.841446543163, 'Parcel': 417982.0}, {'distance': 1576.0859573641103, 'Parcel': 417982.0}, {'distance': 1789.916126359107, 'Parcel': 417982.0}, {'distance': 2045.9419711236899, 'Parcel': 417982.0}, {'distance': 5301.0314493797, 'Parcel': 417982.0}]",
#  1: "[{'distance': 627.9759602088635, 'Parcel': 159195.0}, {'distance': 727.9218882546016, 'Parcel': 159195.0}, {'distance': 888.6035732542174, 'Parcel': 159195.0}, {'distance': 2115.804907287013, 'Parcel': 159195.0}, {'distance': 2613.971148156339, 'Parcel': 159195.0}, {'distance': 2855.7003143880042, 'Parcel': 159195.0}, {'distance': 4035.040023989886, 'Parcel': 159195.0}, {'distance': 5658.41004580807, 'Parcel': 159195.0}]",
# ...

# %%
def weighted_BCR(df, result_ss):
    print(df.Nearest)
    [print(i) for i in df["Nearest"].to_dict()]
#     weighted_Parcels = [print(i["Parcel"]) for i in df.Nearest]

#     return (df.Buyout_Savings + result_ss[result_ss.Parcel in weighted_Parcels].Buyout_Savings.sum()) / (
#             df.Buyouts_Cost + result_ss[result_ss.Parcel in weighted_Parcels].Buyouts_Cost.sum())

weighted_Parcels = [int(i["Parcel"]) for i in df.Nearest]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-47ba30c0d39c> in <module>()
#       8 #             df.Buyouts_Cost + result_ss[result_ss.Parcel in weighted_Parcels].Buyouts_Cost.sum())
#       9
# ---> 10 weighted_Parcels = [int(i["Parcel"]) for i in df.Nearest]
#
# <ipython-input-62-47ba30c0d39c> in <listcomp>(.0)
#       8 #             df.Buyouts_Cost + result_ss[result_ss.Parcel in weighted_Parcels].Buyouts_Cost.sum())
#       9
# ---> 10 weighted_Parcels = [int(i["Parcel"]) for i in df.Nearest]
#
# TypeError: string indices must be integers
